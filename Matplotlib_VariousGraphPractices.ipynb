# %% [markdown]
# # Pandas Data Visualization Exercise
#
# Hi guys,<br>
# Welcome to the pandas data visualization exercises lecture!<br>
#
# Let's go through a quick exercise to review the pandas built-in visualization capabilities. Run the first cell to import required libraries and to create a dataset for use in the exercises below. <br>
# *`np.random.seed(1)` to get the repeatable results.*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(1)
df = pd.DataFrame(np.random.rand(1000,4),columns=['a', 'b', 'c','d'])
#df = pd.DataFrame(np.random.randn(1000,4),columns=['a', 'b', 'c','d'])
# %matplotlib inline

# %% [markdown]
# **How many entries we have in our dataframe?**

# %%
# Code goes here!
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
# a    1000 non-null float64
# b    1000 non-null float64
# c    1000 non-null float64
# d    1000 non-null float64
# dtypes: float64(4)
# memory usage: 31.3 KB

# %% [markdown]
# **Check the head of the dataframe?**

# %%
# Code goes here!
df.head()
# Out:
#           a         b         c         d
# 0  0.417022  0.720324  0.000114  0.302333
# 1  0.146756  0.092339  0.186260  0.345561
# 2  0.396767  0.538817  0.419195  0.685220
# 3  0.204452  0.878117  0.027388  0.670468
# 4  0.417305  0.558690  0.140387  0.198101

# %%
# Out:
#           a         b         c         d
# 0  0.417022  0.720324  0.000114  0.302333
# 1  0.146756  0.092339  0.186260  0.345561
# 2  0.396767  0.538817  0.419195  0.685220
# 3  0.204452  0.878117  0.027388  0.670468
# 4  0.417305  0.558690  0.140387  0.198101

# %% [markdown]
# **You have created a dataset `df`. Plot `c vs d` as a scatter plot to recreate the plot below. Try to match the color and size of the data points. You should be able to match the size of the figure as well!**

# %%
# Code goes here
fig = plt.figure()
axes=fig.add_axes([0,1,1.3,.7])
x=df['c']
y=df['d']
area = 40
plt.scatter(x,y,s=area, c='g', alpha=1)

# %% [markdown]
# ** Create a histogram of the 'd' column.**

# %%
# Code goes here!
dd=df['d']

plt.ylabel('Frequency')

plt.hist(dd, facecolor='b', alpha=.7)
# Out:
# (array([ 85.,  98., 100., 104.,  89.,  97., 106., 103., 104., 114.]),
#  array([9.69506877e-05, 9.97625981e-02, 1.99428246e-01, 2.99093893e-01,
#         3.98759540e-01, 4.98425188e-01, 5.98090835e-01, 6.97756483e-01,
#         7.97422130e-01, 8.97087778e-01, 9.96753425e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ** Change style sheets to set for 'bmh' and add more bins (e.g. 50) to the above plot.**

# %%
# Code goes here!
plt.style.use('bmh')


def plot_beta_hist(ax, a, b):
    ax.hist(dd, histtype="stepfilled", bins=50,facecolor='b', alpha=0.8, density=True)


fig, ax = plt.subplots()
plot_beta_hist(ax, 10, 10)
plot_beta_hist(ax, 4, 12)
plot_beta_hist(ax, 50, 12)
plot_beta_hist(ax, 6, 55)
plt.ylabel('Frequency')


plt.show()

# %% [markdown]
# **Create a scatter plot for a vs b. How to use the s parameter to indicate the size of the data point based of col d?**<br>

# %%
# Code goes here!
fig = plt.figure()
axes=fig.add_axes([2,1,.5,.5])
x=df['a']
y=df['b']
area = 30
plt.scatter(x,y,s=area, c='g', alpha=1)

# %% [markdown]
# **Recreate the plot below**

# %%
# Code goes here!
plt.hexbin(x,y, gridsize=(20,15), bins=20, marginals=True)

# %% [markdown]
# ** Create a kde plot of the 'd' column **

# %%
# Code goes here!

ax = df['d'].plot.kde()

# %% [markdown]
# **Create a boxplot comparing all columns in the data.**<br>
# Hint: use `color = dict(boxes='DarkGreen', whiskers='DarkOrange',medians='DarkBlue', caps='Gray')` and `sym = 'r+'`

# %%
# Code goes here!
color = dict(boxes='DarkGreen', whiskers='DarkOrange',medians='DarkBlue', caps='Gray',sym = 'r+')
 
# Creating plot
plt.boxplot(df)
 
# show plot
plt.show()

# %% [markdown]
# ** Create an area plot of all the columns for just the rows up to 20.**

# %%
# Code goes here!
bx = df[0:20].plot.area()

# %% [markdown]
# **Try moving the legend in the plot above and display it outside the plot, shown below** [Hint](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas) also [gca](https://stackoverflow.com/questions/27221009/fig-gca-vs-fig-add-subplot).....*If `f` is a variable holding a figure, `f.gca()` returns the axes associated with the figure.*

# %%
# Code goes here!
fig = plt.figure()


df[1:21].plot.area()
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Great Job!
